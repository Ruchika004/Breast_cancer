# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset =pd.read_csv("Cancer_Data.csv")

# %%
dataset
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Length: 569, dtype: bool

# %%
dataset.isnull().sum()/len(dataset)*100
# Out:
# id                           0.0
# diagnosis                    0.0
# radius_mean                  0.0
# texture_mean                 0.0
# perimeter_mean               0.0
# area_mean                    0.0
# smoothness_mean              0.0
# compactness_mean             0.0
# concavity_mean               0.0
# concave points_mean          0.0
# symmetry_mean                0.0
# fractal_dimension_mean       0.0
# radius_se                    0.0
# texture_se                   0.0
# perimeter_se                 0.0
# area_se                      0.0
# smoothness_se                0.0
# compactness_se               0.0
# concavity_se                 0.0
# concave points_se            0.0
# symmetry_se                  0.0
# fractal_dimension_se         0.0
# radius_worst                 0.0
# texture_worst                0.0
# perimeter_worst              0.0
# area_worst                   0.0
# smoothness_worst             0.0
# compactness_worst            0.0
# ...

# %%
dataset1 = dataset.drop(["Unnamed: 32"], axis = 1)

# %%
dataset1.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
features = ['radius_mean', 'area_mean', 'concavity_mean']

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'radius_mean', data=dataset1)
plt.title(f"Boxplot for radius_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for radius_mean')

# %%
radius_mean_range = np.max(dataset1['radius_mean'])-np.min(dataset1['radius_mean'])
print(radius_mean_range)
# Out:
# 21.128999999999998

# %%
std_radius_mean = np.std(dataset1['radius_mean'])
std_radius_mean
# Out:
# 3.5209507607110626

# %%
dataset1['new_radius_mean']=(dataset1['radius_mean'] - dataset1['radius_mean'].mean())/dataset1['radius_mean'].std()

# %%
dataset1
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     1.096100         10.38          122.80     1001.0
# 1      842517         M     1.828212         17.77          132.90     1326.0
# 2    84300903         M     1.578499         21.25          130.00     1203.0
# 3    84348301         M    -0.768233         20.38           77.58      386.1
# 4    84358402         M     1.748758         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     2.109139         22.39          142.00     1479.0
# 565    926682         M     1.703356         28.25          131.20     1261.0
# 566    926954         M     0.701667         28.08          108.30      858.1
# 567    927241         M     1.836725         29.33          140.10     1265.0
# 568     92751         B    -1.806811         24.54           47.92      181.0
#
# ...

# %%
upper_limit = dataset['radius_mean'].mean()+3*dataset['radius_mean'].std()
lower_limit = dataset['radius_mean'].mean()-3*dataset['radius_mean'].std()

# %%
upper_limit
# Out:
# 24.699438218530787

# %%
lower_limit
# Out:
# 3.5551452612583176

# %%
dataset1['radius_mean'] = np.where(dataset['radius_mean'] > upper_limit, upper_limit,
                                  np.where(dataset['radius_mean']<lower_limit, lower_limit,dataset['radius_mean']))

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'radius_mean', data=dataset1)
plt.title(f"Boxplot for radius_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for radius_mean')

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'area_mean', data=dataset1)
plt.title(f"Boxplot for area_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for area_mean')

# %%
upper_limit_am = dataset1['area_mean'].mean()+3*dataset1['area_mean'].std()
lower_limit_am = dataset1['area_mean'].mean()-3*dataset1['area_mean'].std()

# %%
upper_limit_am
# Out:
# 1710.6314912356436

# %%
lower_limit_am
# Out:
# -400.8532838542726

# %%
dataset1['area_mean'] = np.where(dataset1['area_mean'] > upper_limit_am, upper_limit_am,
                                 np.where(dataset1['area_mean'] < lower_limit_am, lower_limit_am,dataset1['area_mean']))

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'area_mean', data=dataset1)
plt.title(f"Boxplot for area_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for area_mean')

# %%
dataset1['radius_mean'].skew ()
# Out:
# 0.9423795716730992

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'concavity_mean', data=dataset1)
plt.title(f"Boxplot for concavity_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for concavity_mean')

# %%
upper_limit_cm = dataset1['concavity_mean'].mean()+3*dataset1['concavity_mean'].std()
lower_limit_cm = dataset1['concavity_mean'].mean()-3*dataset1['concavity_mean'].std()

# %%
upper_limit_cm
# Out:
# 0.3279587419409037

# %%
lower_limit_cm
# Out:
# -0.1503601103064573

# %%
dataset1[(dataset1['concavity_mean']>upper_limit_cm) | (dataset1['concavity_mean']< lower_limit_cm)]
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 78     8610862         M       20.180         23.97          143.70
# 82     8611555         M       25.220         24.91          171.50
# 108      86355         M       22.270         19.67          152.80
# 122     865423         M       24.250         20.20          166.20
# 152    8710441         B        9.731         15.34           63.78
# 202     878796         M       23.290         26.67          158.90
# 352     899987         M       25.730         17.46          174.20
# 461  911296202         M       27.420         26.27          186.90
# 567     927241         M       20.600         29.33          140.10
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 78      1245.0           0.1286            0.3454          0.3754
# 82      1878.0           0.1063            0.2665          0.3339
# 108     1509.0           0.1326            0.2768          0.4264
# ...

# %%
dataset1['concavity_mean'] = np.where(dataset1['concavity_mean'] > upper_limit_am, upper_limit_am,
                                 np.where(dataset1['concavity_mean'] < lower_limit_am, lower_limit_am,dataset1['concavity_mean']))

# %%
dataset1['concavity_mean']
# Out:
# 0      0.30010
# 1      0.08690
# 2      0.19740
# 3      0.24140
# 4      0.19800
#         ...
# 564    0.24390
# 565    0.14400
# 566    0.09251
# 567    0.35140
# 568    0.00000
# Name: concavity_mean, Length: 569, dtype: float64

# %%
dataset1.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.109361     19.289649       91.969033   649.964766
# std    1.250206e+08     3.462910      4.301036       24.298981   332.345102
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    24.699438     39.280000      188.500000  1710.631491
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
plt.figure(figsize = (15,8))
plt.subplot(1,2,1)
sns.distplot(dataset1['area_mean'])

plt.subplot(1,2,2)
plt.subplot(1,2,2)
sns.distplot(dataset1['radius_mean'])

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17068\1518493251.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset1['area_mean'])
# C:\Users\User\AppData\Local\Temp\ipykernel_17068\1518493251.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
q1 = np.percentile(dataset1['radius_mean'], 25)
q3 = np.percentile(dataset1['radius_mean'], 75)
IQR = q3-q1

# %%
pos_outlier = q3+1.5*IQR
neg_outlier = q1-1.5*IQR

# %%
dataset1['radius_mean'] = np.where(dataset1['radius_mean'] > pos_outlier, pos_outlier,
                                np.where(dataset1['radius_mean']< neg_outlier, neg_outlier, dataset['radius_mean']))

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'radius_mean', data=dataset1)
plt.title(f"Boxplot for radius_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for radius_mean')

# %%
Q1 = np.percentile(dataset1['area_mean'], 25)
Q3 = np.percentile(dataset1['area_mean'], 75)
IQR_am = Q3-Q1

# %%
pos_outlier_am = Q3+1.5*IQR_am
neg_outlier_am = Q1-1.5*IQR_am

# %%
dataset1['area_mean'] = np.where(dataset1['area_mean'] > pos_outlier_am, pos_outlier_am,
                                np.where(dataset1['area_mean']< neg_outlier_am, neg_outlier_am, dataset['area_mean']))

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'area_mean', data=dataset1)
plt.title(f"Boxplot for area_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for area_mean')

# %%
Q_1 = np.percentile(dataset1['concavity_mean'], 25)
Q_3 = np.percentile(dataset1['concavity_mean'], 75)
IQR_cm = Q_3-Q_1

# %%
pos_outlier_cm = Q_3+1.5*IQR_cm
neg_outlier_cm = Q_1-1.5*IQR_cm

# %%
dataset1['concavity_mean'] = np.where(dataset1['concavity_mean'] > pos_outlier_cm, pos_outlier_cm,
                                np.where(dataset1['concavity_mean']< neg_outlier_cm, neg_outlier_cm, dataset['concavity_mean']))

# %%
plt.figure(figsize = (5,4))
sns.boxplot(y = 'concavity_mean', data=dataset1)
plt.title(f"Boxplot for concavity_mean")
# Out:
# Text(0.5, 1.0, 'Boxplot for concavity_mean')

# %%
dataset1['concavity_mean'].skew()
# Out:
# 1.0238589790511423

# %%
dataset1['area_mean'].skew()
# Out:
# 0.9228836201785272

# %%
dataset1['radius_mean'].skew()
# Out:
# 0.6559525926745047
